# %%
# 1
user_bill_units = int(input("enter your units : "))

if user_bill_units <= 100:
    bill = 0
    print("you'r bill is 0")
elif 100 > user_bill_units <=200:
    bill = (user_bill_units - 100) * 5
elif user_bill_units > 200:
    bill = (100 * 5) + ((user_bill_units - 200) * 10)

print("electricity bill : " , bill)
# Out:
# enter your units :  560
# electricity bill :  4100

# %%
# 2
user_marks = int(input("enter your marks : "))

if  user_marks > 100 or user_marks <= 0:
    print(" invalid marks")
elif user_marks > 90:
    print("A")
elif 80 < user_marks <= 90:
    print("B")
elif 60 <= user_marks <= 80:
    print("C")
else:
    print("D")
# Out:
# enter your marks :  44
# D

# %%
# 3
user_age1 = int(input("enter first user age : "))
user_age2 = int(input("enter second user age : "))
user_age3 = int(input("enter three user age : "))
user_age4 = int(input("enter four user age : "))

if user_age1 < user_age2 and user_age1 < user_age3 and user_age1 < user_age4:
    print("first user is the youngest among all")
elif user_age2 < user_age3 and user_age2 < user_age4:
    print("second user is the youngest among all")
elif user_age3 < user_age4:
    print("user three is youngest among all")
else:
    print("user four is youngest")
# Out:
# enter first user age :  56
# enter second user age :  78
# enter three user age :  12
# enter four user age :  34
# user three is youngest among all

# %%
#4
user_salary = int(input("enter the user salary : "))
user_years_of_experience = int(input("enter user's years of experience : " ))
if user_years_of_experience > 10:
    print(f"Bonus = {(user_salary) + (user_salary/100)*10}")
elif 6 <= user_years_of_experience <= 10:
    print(f"Bonus = {(user_salary) + (user_salary/100)*8}")
elif user_years_of_experience < 6:
    print(f"Bonus = {(user_salary) + (user_salary/100)*5}")
# Out:
# enter the user salary :  70000
# enter user's years of experience :  3
# Bonus = 73500.0

# %%
# 5
number1 = int(input("enter the number1 : "))
number2 = int(input("enter the number2 : "))
number3 = int(input("enter the number3 : "))

if number1 == number2 == number3:
    print("all numbers are equal")
elif number3 < number1 < number2 or number2 < number1 < number3 :
    print("number1 is the second largest ")
elif number1 < number2 < number3 or number3 < number2 < number1:
    print(" number2 is the second largest number")
elif number1 < number3 < number2 or number2 < number3 < number1:
    print("number3 is the second largest number")
# Out:
# enter the number1 :  45
# enter the number2 :  34
# enter the number3 :  76
# number1 is the second largest

# %%
# 6
marked_price = int(input("enter the marked price : "))

if marked_price > 10000:
    net_amount = (marked_price - (0.2*marked_price))
    print("you got 20% discount , Net Amount : " ,net_amount)
                                 
elif 7000 < marked_price <= 10000:
    net_amount = (marked_price - (0.15*marked_price))
    print("you got 15% discount ,Net Amount : " ,net_amount)
elif marked_price <= 7000:
    net_amount = (marked_price - (0.1*marked_price))
    print("you got 10% discount ,Net Amount : " ,net_amount)
# Out:
# enter the marked price :  6700
# you got 10% discount ,Net Amount :  6030.0

# %%
# 7
user_marks_science = int(input("enter the marks science : "))
user_marks_maths = int(input("enter the marks maths: "))
user_marks_english = int(input("enter the marks english: "))
user_marks_social = int(input("enter the marks social: "))

if user_marks_science>80 and user_marks_maths>80 and user_marks_english>80 and user_marks_social>80 :
    print("science")
elif user_marks_english>80 and user_marks_maths>50 and user_marks_science>50 :
    print("commerce")
elif user_marks_science>80 and user_marks_social>80 :
    print("humanities")
else:
    print("no stream")
# Out:
# enter the marks science :  89
# enter the marks maths:  57
# enter the marks english:  82
# enter the marks social:  88
# commerce

# %%
# 8
user_number = int(input("enter the number : "))

if user_number % 5 == 0:
    print("number is divisible by 5 , hello")
else:
    print("number is not divisible by 5 , bye")
# Out:
# enter the number :  67
# number is not divisible by 5 , bye
