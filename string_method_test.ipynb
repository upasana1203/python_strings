# %%
string1 = "python"
string2 = "development"
final_string = string1 +" "+ string2
print(final_string)
# Out:
# python development

# %%
list = ["python" ,"web", "development" , "with"]
print( " ".join(list))
# Out:
# python web development with

# %%
string1.find("o")
# Out:
# 4

# %%
print(len(string1))
# Out:
# 6

# %%
string1.upper()
# Out:
# 'PYTHON'

# %%
string1.lower()
# Out:
# 'python'

# %%
string1.replace("o" , "n")
# Out:
# 'pythnn'

# %%
string1.split("t")       #it would not print the delimiter on which bases we have splt the string
# Out:
# ['py', 'hon']

# %%
string1.startswith("t")
# Out:
# False

# %%
string1.endswith("o")
# Out:
# False

# %%
string3 = "     with   "
string3.strip()
# Out:
# 'with'

# %%
string4 = "data"
string4.find("a")
# Out:
# 1

# %%
string4.count("a")
# Out:
# 2

# %%
string4.isalpha()
# Out:
# True

# %%
string5 = "12345678"
string5.isnumeric()
# Out:
# True

# %%
# palindrome
string6 = "deed"
reversed_string = string6[::-1]
if reversed_string == string6:
    print("True")
else:
    print("False")
# Out:
# True

# %%
# reverse
string5[::-1]
# Out:
# '87654321'

# %%
first_placeholder = "development" 
second_placeholder = "dsa"
print(f"we need to master {first_placeholder} , and have slight knowledge about {second_placeholder}")
# Out:
# we need to master development , and have slight knowledge about dsa

# %%
string7 = "python is a fun language"
string7[7:16:1]
# Out:
# 'is a fun '

# %%
string ="python is a fun language"
new_string = string.maketrans("a" , "e")
print(string.translate(new_string))
# Out:
# python is e fun lenguege
